# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for x in '0123456789':
    s = int(x+'B09', 17) + int(x+'8E8', 15)
    if s%155==0:
        a=s//155
        print(a)
        break
# Out:
# 194

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 2715.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(a,x):
    c=''
    while a!=0:
        c+=str(a%x)
        a=a//x
    return c[::-1]
print(f(125+25**3+5**9,5).count('0'))
# Out:
# 7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(a,x):
    c=''
    while a!=0:
        c+=str(a%x)
        a=a//x
    return c[::-1]
print(f(4**511+2**511-511,2).count('1'))
# Out:
# 504

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# s = int(x+'B09', 17) + int(x+'8E8', 15)

alp = sorted('0123456789QWERTYUIOPASDFGHJKLZXCVBNM')
for p in range (7,37):
    for x in alp[0:p]:
        for y in alp[0:p]:
            for z in alp[0:p]:
                if int(y+'4'+y, p) + int(y+'65', p) == 3+3*int(p)+int(z)*int(p)**2+int(x)*int(p)**3:
                    a=int(x+y+z,p)
                    print(a)
                    break
# Out:
# 117
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 8
#       6 for y in alp[0:p]:
#       7     for z in alp[0:p]:
# ----> 8         if int(y+'4'+y, p) + int(y+'65', p) == 3+3*int(p)+int(z)*int(p)**2+int(x)*int(p)**3:
#       9             a=int(x+y+z,p)
#      10             print(a)
#
# ValueError: invalid literal for int() with base 10: 'A'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s=0
d=0
g=0
h=0
l=0
def f(a,x):
    c=''
    while a!=0:
        c+=str(a%x)
        a=a//x
    return c[::-1]

for x in range(0,32):
    s=9+x*32+9*32**2+7*32**3+32**4 + 7*128**3+x*128**2+9*128+3
    d=f(s,4)
    if d.count('0')>g:
        g=d.count('0')
        h = d
for n in h:
    l+=int(n)
print(l)
# Out:
# 17
